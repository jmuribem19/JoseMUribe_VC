# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import math

# %%
im=cv.imread('/content/drive/MyDrive/EAFIT/2024-2/Visión por computadora/cat (1).jpg')
green=im[:,:,1]
plt.imshow(cv.cvtColor(im, cv.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv.cvtColor(green, cv.COLOR_BGR2RGB))
plt.show()

# %%
escaled = green/255

# %%
vert = np.array([[-1,-2,-1],
                  [0,0,0],
                  [1,2,1]])
vert
# Out:
# array([[-1, -2, -1],
#        [ 0,  0,  0],
#        [ 1,  2,  1]])

# %%
hor = np.array([[1,0,-1],
                     [2,0,-2],
                     [1,0,-1]])
hor
# Out:
# array([[ 1,  0, -1],
#        [ 2,  0, -2],
#        [ 1,  0, -1]])

# %%
imVer=cv.filter2D(escaled,-1,vert)
plt.imshow(imVer, cmap="gray")
plt.show()

# %%
imHor=cv.filter2D(escaled,-1,hor)
plt.imshow(imHor,cmap="gray")
plt.show()

# %%
sobel = np.sqrt(imHor**2 + imVer**2)
plt.imshow(sobel, cmap="gray")
plt.show()
